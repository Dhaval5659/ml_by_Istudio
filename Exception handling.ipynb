# %%
try:
    x=int(input("Enter any number "))
    y=int(input("Enter any number "))
    
    ans=x/y
    print(ans)
    
except ZeroDivisionError:
    print("please enter value other than zero, you are dividing with 0.")
    
except ValueError:
    print("Please enter the integer type of value.")
    
finally:
    print("I am always going to run")
# Out:
# Enter any number 0
# Enter any number 2
# 0.0
# I am always going to run
