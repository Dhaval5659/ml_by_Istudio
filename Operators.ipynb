# %% [markdown]
# # Operators:

# %% [markdown]
# ## Arithematic Operators:

# %% [raw]
# +,-,/,*,**,%,//

# %%
a=10
b=20
print(a+b)
# Out:
# 30

# %%
2**3
# Out:
# 8

# %%
#floor division

# %%
10/5
# Out:
# 2.0

# %%
10//5
# Out:
# 2

# %%
13/2
# Out:
# 6.5

# %%
13//2
# Out:
# 6

# %%
30%5
# Out:
# 0

# %%
24%3
# Out:
# 0

# %%
53%2
# Out:
# 1

# %% [markdown]
# ## Assignment Operators:

# %% [raw]
# =, =+, -=,*=, /=,......

# %%
var = 10 
var+=20  #var = var+20

# %%
print(var)
# Out:
# 30

# %% [markdown]
# ## Comparison Operators:

# %% [raw]
# >,<,>=,<=,!=,==

# %%
a<50
# Out:
# True

# %%
a>50
# Out:
# False

# %%
a!=10
# Out:
# False

# %%
a
# Out:
# 10

# %% [markdown]
# ## Logical Operators:

# %%
x=10
y=40

x%2==0 and y==50
# Out:
# False

# %%
x%2==0 or y==50
# Out:
# True

# %%
not(x%2==0 and y==50)
# Out:
# True

# %% [markdown]
# ## Bitwise Operator:

# %% [raw]
# and(&), or(|), not(~)

# %% [markdown]
# ## Membership Operators:

# %%
# in, not in

list_1 = [10,20,30,40]
40 in list_1
# Out:
# True

# %%
50 in list_1
# Out:
# False

# %%
50 not in list_1
# Out:
# True

# %% [markdown]
# ## Identity Operators:

# %%
#is, is not

# %%
a=20
b=30

# %%
id(a)
# Out:
# 140720761050504

# %%
id(b)
# Out:
# 140720761050824

# %%
a is b
# Out:
# False

# %%
x=20

# %%
id(x)
# Out:
# 140720761050504

# %%
a is x
# Out:
# True
