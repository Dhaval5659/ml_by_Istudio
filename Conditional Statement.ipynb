# %% [raw]
# Contional statemets are the part of python program which we use whenever we want the block code to get executed
# on the basis of some condition
#
# syntax:
#
# if condition:
#     block of code
#     ...
#
# else:
#     block of code
#     ...

# %%
#find out if the number is divisible by 2 or not
num_1=4
if num_1%2==0:
    print("Yes it is divisible by 2")
else:
    print("not divisible by 2")
# Out:
# Yes it is divisible by 2

# %%
# if elif else
if num_1>5:
    print("yes it is:")
elif num_1==4:
    print("yes it is: 2")
else:
    print("Nothing is matching:")
# Out:
# yes it is:
