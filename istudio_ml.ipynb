# %% [markdown]
# # Data Type in Python:

# %% [markdown]
# 1. primitive data: 1. It is homogenous in nature and hava the property that capture only one value:
#         1. int
#         2. float
#         3. String
#         4. Bool
#         5. None

# %% [markdown]
# ## Int

# %%
num_1 = 56
print(num_1)
# Out:
# 56

# %%
#type() is a builtin function that helps up tu judge the data type of identifier

type(num_1)
print(type(num_1))
# Out:
# <class 'int'>

# %% [markdown]
# ## Float:

# %%
x = 56.0
type(x)
# Out:
# float

# %% [markdown]
# ## String:

# %%
str_1= "hey today is sunday."
type(str_1)
# Out:
# str

# %%
print(str_1)
# Out:
# hey today is sunday.

# %% [markdown]
# ## Bool:

# %%
var =True
type(var)
# Out:
# bool

# %%
print(var)
# Out:
# True

# %%
xyz = None

# %%
#is python is case sensative? -> YES

# %% [markdown]
# # Non Primitive Data

# %% [markdown]
# 1. List
# 2. Tuple
# 3. Set
# 4. Dict

# %% [markdown]
# # List:

# %% [raw]
# ---> List is always going to get declare inside the sqear bracket.
# ---> List follows indexing of both types forward indexing and backword indexing.
# ---> forward indexing always goes from L to R start from 0 where backword indexing start from -1 goes from R to L.

# %%
list_1=[10,20,30,40,"String",True,None]
print(list_1)
# Out:
# [10, 20, 30, 40, 'String', True, None]

# %%
print(list_1[5])      #forward indexing
# Out:
# True

# %%
print(list_1[-1])     #backword indexing
# Out:
# None

# %%
list_1.append("hey")

# %%
print(list_1)
# Out:
# [10, 20, 30, 40, 'String', True, None, 'hey']

# %%
# lists are mutable in nature.

# %%
list_1[6]="Hello"

# %%
print(list_1)
# Out:
# [10, 20, 30, 40, 'String', True, 'Hello', 'hey']

# %% [markdown]
# ## Tuple:

# %%
tuple_1=(10, 20, 30, 40, 'String', True, None,[10,20,30])

# %%
print(tuple_1)
# Out:
# (10, 20, 30, 40, 'String', True, None, [10, 20, 30])

# %%
print(type(tuple_1))
# Out:
# <class 'tuple'>

# %% [raw]
# Tuple:
#     1. we can declare any data inside the tuple
#     2. Tuple follows indexing
#     3. lista and tuples boths follows indexing and slicing.
#     4. imutable in nature
#
# syntax of slicing:
#     tuple_1[start_index:end_index+1:stride/jumps]

# %%
tuple_1[1:4]
# Out:
# (20, 30, 40)

# %%
print(tuple_1[::2])
# Out:
# (10, 30, 'String', None)

# %%
print(tuple_1[-2:-5:-1])
# Out:
# (None, True, 'String')

# %%
help(tuple)
# Out:
# Help on class tuple in module builtins:
#
# class tuple(object)
#  |  tuple(iterable=(), /)
#  |
#  |  Built-in immutable sequence.
#  |
#  |  If no argument is given, the constructor returns an empty tuple.
#  |  If iterable is specified the tuple is initialized from iterable's items.
#  |
#  |  If the argument is a tuple, the return value is the same object.
#  |
#  |  Built-in subclasses:
#  |      asyncgen_hooks
#  |      UnraisableHookArgs
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(self, key, /)
#  |      Return self[key].
#  |
#  |  __getnewargs__(self, /)
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
# ...

# %% [markdown]
# # Sets:

# %%
set_1 = {10,23.4,"hey",True}
print(set_1)
# Out:
# {True, 10, 'hey', 23.4}

# %% [raw]
# fSets:
# 1. Sets are unordered in nature.
# 2. Sets does no follows indexing.
# 3. Sets elements are unique in nature.
# 4. Sets when we want to declare as empty one we need to use built in function set

# %%
set_2={10,10,20,20,30,40,40}
print(set_2)
# Out:
# {40, 10, 20, 30}

# %%
set_2.add(300)
print(set_2)
# Out:
# {40, 10, 300, 20, 30}

# %%
list_empty=[]
type(list_empty)
# Out:
# list

# %% [markdown]
# # Dictionary:

# %%
dict_1={"name":"Dhaval","Study":"Istudeo","age":25,1:4}
print(dict_1)
# Out:
# {'name': 'Dhaval', 'Study': 'Istudeo', 'age': 25, 1: 4}

# %%
dict_1.keys()
# Out:
# dict_keys(['name', 'Study', 'age'])

# %%
dict_1.values()
# Out:
# dict_values(['Dhaval', 'Istudeo', 25])

# %%
type(dict_1)
# Out:
# dict

# %% [raw]
# dict:
# 1. Dict is the combination of different key value pairs.
# 2. now there are diff properties for the key and the value of the dict.
# keys:
# 1. Keys only accepts primitive data type and tuples in it.
# 2. Key are immutable in nature.
# 3. Keys are unique.
#
# values:
# 1. We can declare any data types for the values
# 2. Values can be duplicated.
# 3. Values are mutable in nature.

# %%
 "name" in dict_1
# Out:
# True

# %%
del?
# Out:
# Object `del` not found.

# %%
del dict_1["name"]

# %%
print(dict_1.get(1,4))
# Out:
# 4
